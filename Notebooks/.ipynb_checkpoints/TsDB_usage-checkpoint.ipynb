# %% [markdown]
# # TsDB  Usage
#
# * Setup
# * Connect to DB
# * Table structure
# * Views
# * Read data from TsDB
# * Import Data

# %% [markdown]
# ## Resources
#
# * Learning with Kaggle
#   * [Kaggle - Python](https://www.kaggle.com/learn/python)
#   * [Kaggle - Pandas](https://www.kaggle.com/learn/pandas)
#   * [Kaggle - SQL intro](https://www.kaggle.com/learn/intro-to-sql)
#
# * Docs
#   * [Dash/Plotly](http://dash.plotly.com/)
#   * [Pandas](https://pandas.pydata.org/pandas-docs/stable/user_guide/index.html#user-guide)
#   * [TimescaleDB](https://docs.timescale.com/latest/introduction)
#   * [SQL Tutorial](https://www.w3schools.com/sql/default.asp)
# * Cheat Sheets
#   * [Conda](https://docs.conda.io/projects/conda/en/latest/_downloads/843d9e0198f2a193a3484886fa28163c/conda-cheatsheet.pdf)
#   * [Pandas](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)
#   * [PostgreSQL through SQLAlchemy](https://www.compose.com/articles/using-postgresql-through-sqlalchemy/)

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go
import plotly.figure_factory as FF
import plotly.offline as offline
from datetime import datetime
import glob
import os.path
import pymysql
import sqlconfig # From sqlconfig.py
import pandas as pd
import sqlalchemy
import psycopg2
from tqdm import tqdm
print("Import Complete")
# Out:
# Import Complete

# %% [markdown]
# ## SQL setup
# create [sqlalchemy](https://docs.sqlalchemy.org/en/13/core/engines.html#postgresql) engine to connect to DB
# using SQL credentials from `sqlconfig.py`

# %% [markdown]
# Host IP - 34.68.85.80

# %% [markdown]
# ```python
# passwd = "passwd"  # password for DB
# user = "user"  # Username for DB
# DB = 'cbas'  # name of database
# ```

# %%
passwd = sqlconfig.passwd  # From sqlconfig.py
user = sqlconfig.user  # From sqlconfig.py
DB = 'cbas'  #name of databases to activate

# %%
print("User: "+user) # check user
# Out:
# User: ad

# %%
engine = sqlalchemy.create_engine('postgresql+psycopg2://'+user+':'+passwd+'@34.68.85.80/'+DB)

# %% [markdown]
# ---

# %% [markdown]
# ### DB/table structure

# %% [markdown]
# Databases and tables
#
# ---
#
# ```
# ├─cbas - (Database)
#     └─ Tables
#        ├── cbasdef (data from VM ingestion+(NULL)comfort metrics)
#        ├── values (units and names of values for charting)
#        ├── newlab(*) (NewLab data)
#        ├── telemetry(*) (Telemetry data from CBAS)
# ```
#
# ---

# %% [markdown]
# ### SQL VIEWS
#
# * [Continuous Aggregates](https://docs.timescale.com/latest/api#continuous-aggregates)
#
# * raw
#
# ```SQL
# CREATE VIEW raw AS
# SELECT "sensor","battery", "Air", "Tdb_BME680", "RH_BME680", "P_BME680", "Alt_BME680", "TVOC","ECO2", "RCO2", "Tdb_scd30", "RH_scd30", "Lux", "PM1", "PM25", "PM10"
# FROM cbasdef
# order by timestamp desc;
# ```

# %% [markdown]
# ## Read Data
#
# * [TimescaleDB-"Reading data"](https://docs.timescale.com/latest/using-timescaledb/reading-data)

# %% [markdown]
# Just going to try pulling everythingto see what we have....

# %%
query= ''' 
SELECT * 
FROM cbasdef
'''

# %%
CBAS= pd.read_sql(query,engine,index_col=["timestamp"])
#CBAS
CBAS.head()
# Out:
#                             battery  Tdb_BME680  RH_BME680  P_BME680  \
# timestamp
# 2020-02-27 20:57:57+00:00  4.061965       23.96      18.50     99.69
# 2020-02-27 20:58:59+00:00  4.061965       23.97      18.49     99.69
# 2020-02-27 21:00:01+00:00  4.059721       23.98      18.58     99.69
# 2020-02-27 21:01:02+00:00  4.072067       23.98      18.58     99.69
# 2020-02-27 21:02:04+00:00  4.065333       23.99      18.61     99.69
#
#                            Alt_BME680   TVOC   ECO2   RCO2  Tdb_scd30  \
# timestamp
# 2020-02-27 20:57:57+00:00      100.49   90.0  400.0  638.0      27.55
# 2020-02-27 20:58:59+00:00      100.66   92.0  400.0  636.0      27.57
# 2020-02-27 21:00:01+00:00      100.49   87.0  400.0  640.0      27.56
# 2020-02-27 21:01:02+00:00      100.49   88.0  400.0  644.0      27.59
# 2020-02-27 21:02:04+00:00      101.16  103.0  400.0  650.0      27.59
#
#                            RH_scd30  ...  Ta_adj_fixed_air  \
# timestamp                            ...
# 2020-02-27 20:57:57+00:00     15.55  ...              None
# 2020-02-27 20:58:59+00:00     15.60  ...              None
# 2020-02-27 21:00:01+00:00     15.69  ...              None
# 2020-02-27 21:01:02+00:00     15.71  ...              None
# 2020-02-27 21:02:04+00:00     15.66  ...              None
#
#                            Cooling_effect_fixed_air  SET_fixed_air  \
# timestamp
# 2020-02-27 20:57:57+00:00                      None           None
# 2020-02-27 20:58:59+00:00                      None           None
# 2020-02-27 21:00:01+00:00                      None           None
# 2020-02-27 21:01:02+00:00                      None           None
# 2020-02-27 21:02:04+00:00                      None           None
#
#                            TComf_fixed_air  TempDiff_fixed_air  \
# timestamp
# 2020-02-27 20:57:57+00:00             None                None
# 2020-02-27 20:58:59+00:00             None                None
# 2020-02-27 21:00:01+00:00             None                None
# 2020-02-27 21:01:02+00:00             None                None
# 2020-02-27 21:02:04+00:00             None                None
#
#                           TComfLower_fixed_air TComfUpper_fixed_air  \
# timestamp
# 2020-02-27 20:57:57+00:00                 None                 None
# 2020-02-27 20:58:59+00:00                 None                 None
# 2020-02-27 21:00:01+00:00                 None                 None
# 2020-02-27 21:01:02+00:00                 None                 None
# 2020-02-27 21:02:04+00:00                 None                 None
#
#                           Acceptability_fixed_air Condit_fixed_air epoch
# timestamp
# 2020-02-27 20:57:57+00:00                    None             None   NaT
# 2020-02-27 20:58:59+00:00                    None             None   NaT
# 2020-02-27 21:00:01+00:00                    None             None   NaT
# 2020-02-27 21:01:02+00:00                    None             None   NaT
# 2020-02-27 21:02:04+00:00                    None             None   NaT
#
# [5 rows x 58 columns]

# %%
# What sensors do we have?
CBAS['sensor'].unique()
# Out:
# array(['Moe'], dtype=object)

# %% [markdown]
# ### More Queries

# %% [markdown]
# #### From Now() to interval
# * Starting now() go back to `[interval]`:
# ```SQL
# SELECT *
# FROM [table]
# WHERE timestamp > NOW() - interval '[interval]';
# ```

# %%
query = '''
SELECT * 
FROM cbasdef
WHERE timestamp > NOW() - interval '1 hour';
'''

# %%
CBAS = pd.read_sql(query,engine,index_col=["timestamp"])
#CBAS
CBAS.head()
# Out:
#                             battery  Tdb_BME680  RH_BME680  P_BME680  \
# timestamp
# 2020-04-01 20:30:19+00:00  4.037273       28.12      24.67    100.48
# 2020-04-01 20:30:08+00:00  4.035028       28.13      24.65    100.49
# 2020-04-01 20:30:06+00:00  4.125942      -99.00     -99.00    -99.00
# 2020-04-01 20:29:57+00:00  4.084414       25.57      53.35    100.65
# 2020-04-01 20:29:57+00:00  4.035028       28.13      24.66    100.49
#
#                            Alt_BME680   TVOC   ECO2    RCO2  Tdb_scd30  \
# timestamp
# 2020-04-01 20:30:19+00:00       34.09   50.0  403.0   468.0      31.15
# 2020-04-01 20:30:08+00:00       33.75   50.0  403.0   469.0      31.17
# 2020-04-01 20:30:06+00:00      -99.00  -99.0  -99.0   -99.0     -99.00
# 2020-04-01 20:29:57+00:00       19.75  234.0  610.0  1927.0      27.31
# 2020-04-01 20:29:57+00:00       33.75   64.0  441.0   468.0      31.15
#
#                            RH_scd30  ...  Ta_adj_fixed_air  \
# timestamp                            ...
# 2020-04-01 20:30:19+00:00     20.85  ...              None
# 2020-04-01 20:30:08+00:00     21.07  ...              None
# 2020-04-01 20:30:06+00:00    -99.00  ...              None
# 2020-04-01 20:29:57+00:00     50.89  ...              None
# 2020-04-01 20:29:57+00:00     21.24  ...              None
#
#                            Cooling_effect_fixed_air  SET_fixed_air  \
# timestamp
# 2020-04-01 20:30:19+00:00                      None           None
# 2020-04-01 20:30:08+00:00                      None           None
# 2020-04-01 20:30:06+00:00                      None           None
# 2020-04-01 20:29:57+00:00                      None           None
# 2020-04-01 20:29:57+00:00                      None           None
#
#                            TComf_fixed_air  TempDiff_fixed_air  \
# timestamp
# 2020-04-01 20:30:19+00:00             None                None
# 2020-04-01 20:30:08+00:00             None                None
# 2020-04-01 20:30:06+00:00             None                None
# 2020-04-01 20:29:57+00:00             None                None
# 2020-04-01 20:29:57+00:00             None                None
#
#                           TComfLower_fixed_air TComfUpper_fixed_air  \
# timestamp
# 2020-04-01 20:30:19+00:00                 None                 None
# 2020-04-01 20:30:08+00:00                 None                 None
# 2020-04-01 20:30:06+00:00                 None                 None
# 2020-04-01 20:29:57+00:00                 None                 None
# 2020-04-01 20:29:57+00:00                 None                 None
#
#                           Acceptability_fixed_air Condit_fixed_air  \
# timestamp
# 2020-04-01 20:30:19+00:00                    None             None
# 2020-04-01 20:30:08+00:00                    None             None
# 2020-04-01 20:30:06+00:00                    None             None
# 2020-04-01 20:29:57+00:00                    None             None
# 2020-04-01 20:29:57+00:00                    None             None
#
#                                                epoch
# timestamp
# 2020-04-01 20:30:19+00:00 1970-01-01 00:00:01.585773
# 2020-04-01 20:30:08+00:00 1970-01-01 00:00:01.585773
# 2020-04-01 20:30:06+00:00 1970-01-01 00:00:01.585773
# 2020-04-01 20:29:57+00:00 1970-01-01 00:00:01.585772
# 2020-04-01 20:29:57+00:00 1970-01-01 00:00:01.585772
#
# [5 rows x 58 columns]

# %% [markdown]
# #### SELECT sensor(s)
# * select sensor:
# ```SQL
# SELECT * FROM cbasdef
# WHERE sensor IN ('Moe')
# AND timestamp > NOW() - interval '1 hour';
# ```

# %%
query = '''
SELECT * FROM cbasdef
WHERE sensor IN ('Moe')
AND timestamp > NOW() - interval '1 hour';
'''

# %%
CBAS = pd.read_sql(query,engine,index_col=["timestamp"])
#CBAS
CBAS.head()
# Out:
#                             battery  Tdb_BME680  RH_BME680  P_BME680  \
# timestamp
# 2020-04-01 20:33:13+00:00  4.107984       -99.0      -99.0     -99.0
# 2020-04-01 20:32:11+00:00  4.113596       -99.0      -99.0     -99.0
# 2020-04-01 20:31:08+00:00  4.125942       -99.0      -99.0     -99.0
# 2020-04-01 20:30:06+00:00  4.125942       -99.0      -99.0     -99.0
# 2020-04-01 20:29:03+00:00  4.133799       -99.0      -99.0     -99.0
#
#                            Alt_BME680  TVOC  ECO2  RCO2  Tdb_scd30  RH_scd30  \
# timestamp
# 2020-04-01 20:33:13+00:00       -99.0 -99.0 -99.0 -99.0      -99.0     -99.0
# 2020-04-01 20:32:11+00:00       -99.0 -99.0 -99.0 -99.0      -99.0     -99.0
# 2020-04-01 20:31:08+00:00       -99.0 -99.0 -99.0 -99.0      -99.0     -99.0
# 2020-04-01 20:30:06+00:00       -99.0 -99.0 -99.0 -99.0      -99.0     -99.0
# 2020-04-01 20:29:03+00:00       -99.0 -99.0 -99.0 -99.0      -99.0     -99.0
#
#                            ...  Ta_adj_fixed_air  Cooling_effect_fixed_air  \
# timestamp                  ...
# 2020-04-01 20:33:13+00:00  ...              None                      None
# 2020-04-01 20:32:11+00:00  ...              None                      None
# 2020-04-01 20:31:08+00:00  ...              None                      None
# 2020-04-01 20:30:06+00:00  ...              None                      None
# 2020-04-01 20:29:03+00:00  ...              None                      None
#
#                            SET_fixed_air  TComf_fixed_air  TempDiff_fixed_air  \
# timestamp
# 2020-04-01 20:33:13+00:00           None             None                None
# 2020-04-01 20:32:11+00:00           None             None                None
# 2020-04-01 20:31:08+00:00           None             None                None
# 2020-04-01 20:30:06+00:00           None             None                None
# 2020-04-01 20:29:03+00:00           None             None                None
#
#                           TComfLower_fixed_air TComfUpper_fixed_air  \
# timestamp
# 2020-04-01 20:33:13+00:00                 None                 None
# 2020-04-01 20:32:11+00:00                 None                 None
# 2020-04-01 20:31:08+00:00                 None                 None
# 2020-04-01 20:30:06+00:00                 None                 None
# 2020-04-01 20:29:03+00:00                 None                 None
#
#                           Acceptability_fixed_air Condit_fixed_air  \
# timestamp
# 2020-04-01 20:33:13+00:00                    None             None
# 2020-04-01 20:32:11+00:00                    None             None
# 2020-04-01 20:31:08+00:00                    None             None
# 2020-04-01 20:30:06+00:00                    None             None
# 2020-04-01 20:29:03+00:00                    None             None
#
#                                                epoch
# timestamp
# 2020-04-01 20:33:13+00:00 1970-01-01 00:00:01.585773
# 2020-04-01 20:32:11+00:00 1970-01-01 00:00:01.585773
# 2020-04-01 20:31:08+00:00 1970-01-01 00:00:01.585773
# 2020-04-01 20:30:06+00:00 1970-01-01 00:00:01.585773
# 2020-04-01 20:29:03+00:00 1970-01-01 00:00:01.585772
#
# [5 rows x 58 columns]

# %% [markdown]
# #### time_buckets ([pd.resample](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.resample.html))
#
# * [TimescaleDB-"time_bucket()"](https://docs.timescale.com/latest/api#time_bucket)
#
# * [TimescaleDB-Blog](https://blog.timescale.com/blog/simplified-time-series-analytics-using-the-time_bucket-function/)

# %%
query = '''
SELECT time_bucket('5 minutes', time) AS five_min, "Tdb_BME680"
FROM raw
WHERE sensor IN ('Moe')
AND timestamp > NOW() - interval '1 hour'
GROUPBY five_min;
'''
