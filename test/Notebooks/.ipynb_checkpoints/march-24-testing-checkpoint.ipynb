# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go
import plotly.figure_factory as FF
import plotly.offline as offline
from plotly.subplots import make_subplots
import numpy as np
import pandas as pd
import os.path
from datetime import datetime
from dash.dependencies import Input, Output
import glob
import flask
from tqdm import tqdm
from scipy.constants import convert_temperature
import sqlconfig # From sqlconfig.py
import sqlalchemy
import psycopg2
print("Import Complete")
# Out:
# Import Complete

# %%
passwd = sqlconfig.passwd  # From sqlconfig.py
user = sqlconfig.user  # From sqlconfig.py
DB = 'cbas'  #name of databases to activate 
engine = sqlalchemy.create_engine('postgresql+psycopg2://'+user+':'+passwd+'@34.68.85.80/'+DB)

# %%
# how to get this data in a way we can plot/manipulate

# %%
# think it would be cool if the variable names could be sensor names...that would eliminate df[1]2 XX confusion

# %%
# set a query

# %%
query= ''' 
SELECT * 
FROM cbasdef
'''

# %%
df = pd.read_sql(query,engine,index_col=["timestamp"])

# %%
df.sensor.unique()
# Out:
# array(['BEEM-A', 'BEEM-C', 'BEEM-D', 'Moe', 'protoCBAS-G', None,
#        'protoCBAS-B'], dtype=object)

# %%
sensors = df.sensor.unique()

# %%
sensors
# Out:
# array(['BEEM-A', 'BEEM-C', 'BEEM-D', 'Moe', 'protoCBAS-G', None,
#        'protoCBAS-B'], dtype=object)

# %%
BEEMA = df.where(df["sensor"] = sensors[0])
# Out:
#   File "<ipython-input-15-efa157fba3b4>", line 1
#     BEEMA = df.where(df["sensor"] = sensors[0])
#                      ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
BEEMA = df.where(df["sensor"] == sensors[0])

# %%
BEEMA
# Out:
#                             battery  Tdb_BME680  RH_BME680  P_BME680  \
# timestamp
# 2020-02-27 20:57:57+00:00  4.061965       23.96      18.50     99.69
# 2020-02-27 20:58:59+00:00  4.061965       23.97      18.49     99.69
# 2020-02-27 21:00:01+00:00  4.059721       23.98      18.58     99.69
# 2020-02-27 21:01:02+00:00  4.072067       23.98      18.58     99.69
# 2020-02-27 21:02:04+00:00  4.065333       23.99      18.61     99.69
# ...                             ...         ...        ...       ...
# 2020-02-16 07:40:55+00:00       NaN         NaN        NaN       NaN
# 2020-02-16 07:41:57+00:00       NaN         NaN        NaN       NaN
# 2020-02-16 07:42:59+00:00       NaN         NaN        NaN       NaN
# 2020-02-16 07:44:00+00:00       NaN         NaN        NaN       NaN
# 2020-02-16 07:45:02+00:00       NaN         NaN        NaN       NaN
#
#                            Alt_BME680   TVOC   ECO2   RCO2  Tdb_scd30  \
# timestamp
# ...

# %%
BEEMA.sensor.unique()
# Out:
# array(['BEEM-A', nan], dtype=object)

# %%
#insterted some nulls for sensor column yesterday... gotta take that out

# %%
df = pd.read_sql(query,engine,index_col=["timestamp"])

# %%
df.sensor.unique()
# Out:
# array(['BEEM-A', 'BEEM-C', 'BEEM-D', 'Moe', 'protoCBAS-G', None,
#        'protoCBAS-B'], dtype=object)

# %%
df = pd.read_sql(query,engine,index_col=["timestamp"])

# %%
df.sensor.unique()
# Out:
# array(['BEEM-A', 'BEEM-C', 'BEEM-D', 'Moe', 'protoCBAS-G', 'protoCBAS-B'],
#       dtype=object)

# %%
BEEMA = df.where(df["sensor"] == sensors[0])

# %%
BEEMA
# Out:
#                             battery  Tdb_BME680  RH_BME680  P_BME680  \
# timestamp
# 2020-02-27 20:57:57+00:00  4.061965       23.96      18.50     99.69
# 2020-02-27 20:58:59+00:00  4.061965       23.97      18.49     99.69
# 2020-02-27 21:00:01+00:00  4.059721       23.98      18.58     99.69
# 2020-02-27 21:01:02+00:00  4.072067       23.98      18.58     99.69
# 2020-02-27 21:02:04+00:00  4.065333       23.99      18.61     99.69
# ...                             ...         ...        ...       ...
# 2020-02-16 07:40:55+00:00       NaN         NaN        NaN       NaN
# 2020-02-16 07:41:57+00:00       NaN         NaN        NaN       NaN
# 2020-02-16 07:42:59+00:00       NaN         NaN        NaN       NaN
# 2020-02-16 07:44:00+00:00       NaN         NaN        NaN       NaN
# 2020-02-16 07:45:02+00:00       NaN         NaN        NaN       NaN
#
#                            Alt_BME680   TVOC   ECO2   RCO2  Tdb_scd30  \
# timestamp
# ...

# %%
BEEMA.sensor.unique()
# Out:
# array(['BEEM-A', nan], dtype=object)

# %%
#TF is that nan comming from

# %%
BEEMA.where(BEEMA["sensor"].isnull())
# Out:
#                            battery  Tdb_BME680  RH_BME680  P_BME680  \
# timestamp
# 2020-02-27 20:57:57+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 20:58:59+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 21:00:01+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 21:01:02+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 21:02:04+00:00      NaN         NaN        NaN       NaN
# ...                            ...         ...        ...       ...
# 2020-02-16 07:40:55+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:41:57+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:42:59+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:44:00+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:45:02+00:00      NaN         NaN        NaN       NaN
#
#                            Alt_BME680  TVOC  ECO2  RCO2  Tdb_scd30  RH_scd30  \
# timestamp
# ...

# %%
#oh...

# %%
# we can prob drop all the fully nan rows w no issue

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [battery, Tdb_BME680, RH_BME680, P_BME680, Alt_BME680, TVOC, ECO2, RCO2, Tdb_scd30, RH_scd30, Lux, PM1, PM25, PM10, Air, sensor_SD, note, sensor_note, Coord_X_m, Coord_Y_m, Coord_Z_m, Position_HumanReadable, Wkdy, Hour, Month, TOD, DOY, sensor, UTCI_approx, UTCI_comfortable, UTCI_stressRange, PMV, PPD, Ta_adj, Cooling_effect, SET, running_mean, TComf, TempDiff, TComfLower, TComfUpper, Acceptability, Condit, UTCI_approx_fixed_air, UTCI_comfortable_fixed_air, UTCI_stressRange_fixed_air, PMV_fixed_air, PPD_fixed_air, Ta_adj_fixed_air, Cooling_effect_fixed_air, SET_fixed_air, TComf_fixed_air, TempDiff_fixed_air, TComfLower_fixed_air, TComfUpper_fixed_air, Acceptability_fixed_air, Condit_fixed_air, epoch]
# Index: []
#
# [0 rows x 58 columns]

# %%
df.where(df["sensor"].isnull())
# Out:
#                            battery  Tdb_BME680  RH_BME680  P_BME680  \
# timestamp
# 2020-02-27 20:57:57+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 20:58:59+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 21:00:01+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 21:01:02+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 21:02:04+00:00      NaN         NaN        NaN       NaN
# ...                            ...         ...        ...       ...
# 2020-02-16 07:40:55+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:41:57+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:42:59+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:44:00+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:45:02+00:00      NaN         NaN        NaN       NaN
#
#                            Alt_BME680  TVOC  ECO2  RCO2  Tdb_scd30  RH_scd30  \
# timestamp
# ...

# %%
df.dropna(how='all')
# Out:
#                             battery  Tdb_BME680  RH_BME680  P_BME680  \
# timestamp
# 2020-02-27 20:57:57+00:00  4.061965       23.96      18.50     99.69
# 2020-02-27 20:58:59+00:00  4.061965       23.97      18.49     99.69
# 2020-02-27 21:00:01+00:00  4.059721       23.98      18.58     99.69
# 2020-02-27 21:01:02+00:00  4.072067       23.98      18.58     99.69
# 2020-02-27 21:02:04+00:00  4.065333       23.99      18.61     99.69
# ...                             ...         ...        ...       ...
# 2020-02-16 07:40:55+00:00  3.379546       23.07      18.56    102.56
# 2020-02-16 07:41:57+00:00  3.387403       23.07      18.57    102.56
# 2020-02-16 07:42:59+00:00  3.386281       23.06      18.57    102.55
# 2020-02-16 07:44:00+00:00  3.357098       23.05      18.56    102.55
# 2020-02-16 07:45:02+00:00  3.387403       23.05      18.58    102.55
#
#                            Alt_BME680   TVOC   ECO2   RCO2  Tdb_scd30  \
# timestamp
# ...

# %%
df = df.dropna(how='all')

# %%
df.where(df["sensor"].isnull())
# Out:
#                            battery  Tdb_BME680  RH_BME680  P_BME680  \
# timestamp
# 2020-02-27 20:57:57+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 20:58:59+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 21:00:01+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 21:01:02+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 21:02:04+00:00      NaN         NaN        NaN       NaN
# ...                            ...         ...        ...       ...
# 2020-02-16 07:40:55+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:41:57+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:42:59+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:44:00+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:45:02+00:00      NaN         NaN        NaN       NaN
#
#                            Alt_BME680  TVOC  ECO2  RCO2  Tdb_scd30  RH_scd30  \
# timestamp
# ...

# %%
df.dropna(thresh=2)
# Out:
#                             battery  Tdb_BME680  RH_BME680  P_BME680  \
# timestamp
# 2020-02-27 20:57:57+00:00  4.061965       23.96      18.50     99.69
# 2020-02-27 20:58:59+00:00  4.061965       23.97      18.49     99.69
# 2020-02-27 21:00:01+00:00  4.059721       23.98      18.58     99.69
# 2020-02-27 21:01:02+00:00  4.072067       23.98      18.58     99.69
# 2020-02-27 21:02:04+00:00  4.065333       23.99      18.61     99.69
# ...                             ...         ...        ...       ...
# 2020-02-16 07:40:55+00:00  3.379546       23.07      18.56    102.56
# 2020-02-16 07:41:57+00:00  3.387403       23.07      18.57    102.56
# 2020-02-16 07:42:59+00:00  3.386281       23.06      18.57    102.55
# 2020-02-16 07:44:00+00:00  3.357098       23.05      18.56    102.55
# 2020-02-16 07:45:02+00:00  3.387403       23.05      18.58    102.55
#
#                            Alt_BME680   TVOC   ECO2   RCO2  Tdb_scd30  \
# timestamp
# ...

# %%
df = df.dropna(thresh=2)

# %%
df.where(df["sensor"].isnull())
# Out:
#                            battery  Tdb_BME680  RH_BME680  P_BME680  \
# timestamp
# 2020-02-27 20:57:57+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 20:58:59+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 21:00:01+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 21:01:02+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 21:02:04+00:00      NaN         NaN        NaN       NaN
# ...                            ...         ...        ...       ...
# 2020-02-16 07:40:55+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:41:57+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:42:59+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:44:00+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:45:02+00:00      NaN         NaN        NaN       NaN
#
#                            Alt_BME680  TVOC  ECO2  RCO2  Tdb_scd30  RH_scd30  \
# timestamp
# ...

# %%
df.dropna(thresh=2,inplace=True)

# %%
df.where(df["sensor"].isnull())
# Out:
#                            battery  Tdb_BME680  RH_BME680  P_BME680  \
# timestamp
# 2020-02-27 20:57:57+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 20:58:59+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 21:00:01+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 21:01:02+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 21:02:04+00:00      NaN         NaN        NaN       NaN
# ...                            ...         ...        ...       ...
# 2020-02-16 07:40:55+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:41:57+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:42:59+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:44:00+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:45:02+00:00      NaN         NaN        NaN       NaN
#
#                            Alt_BME680  TVOC  ECO2  RCO2  Tdb_scd30  RH_scd30  \
# timestamp
# ...

# %%
df.dropna(subset=['sensor'],inplace=True)

# %%
df.where(df["sensor"].isnull())
# Out:
#                            battery  Tdb_BME680  RH_BME680  P_BME680  \
# timestamp
# 2020-02-27 20:57:57+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 20:58:59+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 21:00:01+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 21:01:02+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 21:02:04+00:00      NaN         NaN        NaN       NaN
# ...                            ...         ...        ...       ...
# 2020-02-16 07:40:55+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:41:57+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:42:59+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:44:00+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:45:02+00:00      NaN         NaN        NaN       NaN
#
#                            Alt_BME680  TVOC  ECO2  RCO2  Tdb_scd30  RH_scd30  \
# timestamp
# ...

# %%
df.where(df["sensor"].isna())
# Out:
#                            battery  Tdb_BME680  RH_BME680  P_BME680  \
# timestamp
# 2020-02-27 20:57:57+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 20:58:59+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 21:00:01+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 21:01:02+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 21:02:04+00:00      NaN         NaN        NaN       NaN
# ...                            ...         ...        ...       ...
# 2020-02-16 07:40:55+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:41:57+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:42:59+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:44:00+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:45:02+00:00      NaN         NaN        NaN       NaN
#
#                            Alt_BME680  TVOC  ECO2  RCO2  Tdb_scd30  RH_scd30  \
# timestamp
# ...

# %%
pd.isna(df)
# Out:
#                            battery  Tdb_BME680  RH_BME680  P_BME680  \
# timestamp
# 2020-02-27 20:57:57+00:00    False       False      False     False
# 2020-02-27 20:58:59+00:00    False       False      False     False
# 2020-02-27 21:00:01+00:00    False       False      False     False
# 2020-02-27 21:01:02+00:00    False       False      False     False
# 2020-02-27 21:02:04+00:00    False       False      False     False
# ...                            ...         ...        ...       ...
# 2020-02-16 07:40:55+00:00    False       False      False     False
# 2020-02-16 07:41:57+00:00    False       False      False     False
# 2020-02-16 07:42:59+00:00    False       False      False     False
# 2020-02-16 07:44:00+00:00    False       False      False     False
# 2020-02-16 07:45:02+00:00    False       False      False     False
#
#                            Alt_BME680   TVOC   ECO2   RCO2  Tdb_scd30  \
# timestamp
# ...

# %%
# all those other fucking columns...
# note to self, make a view for raw data...

# %%
df.where(df["sensor"].isna())
# Out:
#                            battery  Tdb_BME680  RH_BME680  P_BME680  \
# timestamp
# 2020-02-27 20:57:57+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 20:58:59+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 21:00:01+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 21:01:02+00:00      NaN         NaN        NaN       NaN
# 2020-02-27 21:02:04+00:00      NaN         NaN        NaN       NaN
# ...                            ...         ...        ...       ...
# 2020-02-16 07:40:55+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:41:57+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:42:59+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:44:00+00:00      NaN         NaN        NaN       NaN
# 2020-02-16 07:45:02+00:00      NaN         NaN        NaN       NaN
#
#                            Alt_BME680  TVOC  ECO2  RCO2  Tdb_scd30  RH_scd30  \
# timestamp
# ...

# %%
df.dropna(inplace=True)

# %%
df.where(df["sensor"].isna())
# Out:
# Empty DataFrame
# Columns: [battery, Tdb_BME680, RH_BME680, P_BME680, Alt_BME680, TVOC, ECO2, RCO2, Tdb_scd30, RH_scd30, Lux, PM1, PM25, PM10, Air, sensor_SD, note, sensor_note, Coord_X_m, Coord_Y_m, Coord_Z_m, Position_HumanReadable, Wkdy, Hour, Month, TOD, DOY, sensor, UTCI_approx, UTCI_comfortable, UTCI_stressRange, PMV, PPD, Ta_adj, Cooling_effect, SET, running_mean, TComf, TempDiff, TComfLower, TComfUpper, Acceptability, Condit, UTCI_approx_fixed_air, UTCI_comfortable_fixed_air, UTCI_stressRange_fixed_air, PMV_fixed_air, PPD_fixed_air, Ta_adj_fixed_air, Cooling_effect_fixed_air, SET_fixed_air, TComf_fixed_air, TempDiff_fixed_air, TComfLower_fixed_air, TComfUpper_fixed_air, Acceptability_fixed_air, Condit_fixed_air, epoch]
# Index: []
#
# [0 rows x 58 columns]

# %%
#okay coolbeans

# %%
BEEMA = df.where(df["sensor"] == sensors[0])

# %%
BEEMA.sensor.unique()
# Out:
# array([], dtype=object)

# %%
BEEMA.sensor
# Out:
# Series([], Name: sensor, dtype: object)

# %%
BEEMA
# Out:
# Empty DataFrame
# Columns: [battery, Tdb_BME680, RH_BME680, P_BME680, Alt_BME680, TVOC, ECO2, RCO2, Tdb_scd30, RH_scd30, Lux, PM1, PM25, PM10, Air, sensor_SD, note, sensor_note, Coord_X_m, Coord_Y_m, Coord_Z_m, Position_HumanReadable, Wkdy, Hour, Month, TOD, DOY, sensor, UTCI_approx, UTCI_comfortable, UTCI_stressRange, PMV, PPD, Ta_adj, Cooling_effect, SET, running_mean, TComf, TempDiff, TComfLower, TComfUpper, Acceptability, Condit, UTCI_approx_fixed_air, UTCI_comfortable_fixed_air, UTCI_stressRange_fixed_air, PMV_fixed_air, PPD_fixed_air, Ta_adj_fixed_air, Cooling_effect_fixed_air, SET_fixed_air, TComf_fixed_air, TempDiff_fixed_air, TComfLower_fixed_air, TComfUpper_fixed_air, Acceptability_fixed_air, Condit_fixed_air, epoch]
# Index: []
#
# [0 rows x 58 columns]

# %%
df.sensor.unique()
# Out:
# array([], dtype=object)

# %%
df
# Out:
# Empty DataFrame
# Columns: [battery, Tdb_BME680, RH_BME680, P_BME680, Alt_BME680, TVOC, ECO2, RCO2, Tdb_scd30, RH_scd30, Lux, PM1, PM25, PM10, Air, sensor_SD, note, sensor_note, Coord_X_m, Coord_Y_m, Coord_Z_m, Position_HumanReadable, Wkdy, Hour, Month, TOD, DOY, sensor, UTCI_approx, UTCI_comfortable, UTCI_stressRange, PMV, PPD, Ta_adj, Cooling_effect, SET, running_mean, TComf, TempDiff, TComfLower, TComfUpper, Acceptability, Condit, UTCI_approx_fixed_air, UTCI_comfortable_fixed_air, UTCI_stressRange_fixed_air, PMV_fixed_air, PPD_fixed_air, Ta_adj_fixed_air, Cooling_effect_fixed_air, SET_fixed_air, TComf_fixed_air, TempDiff_fixed_air, TComfLower_fixed_air, TComfUpper_fixed_air, Acceptability_fixed_air, Condit_fixed_air, epoch]
# Index: []
#
# [0 rows x 58 columns]

# %%
#oh...right...those columns....
