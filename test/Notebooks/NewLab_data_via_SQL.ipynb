# %% [markdown]
# # Working with NewLab data set using SQL data
# We have data from our Sept-Dec deployment in NL uploded to our SQL DB
#
# I'd like to try:
# * pulling this data
# * plotting
# * SQL query experimentation
# * SQL Insert experminentation

# %% [markdown]
# ## FYI sqlconfig
# to ```import sqlconfig``` the file "sqlconfig.py" should be in this folder or directory adjusted acordingly
# This file has the user/password for SQL connection and is in the gitignore so you will have to create this locally
#
# ---
# Create sqlconfig.py as:
# ```python
# # .gitignore should include reference to config.py
# passwd = "[password]"
# user = "[username]"
# ```
# ---

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go
import plotly.figure_factory as FF
from datetime import datetime
import glob
import os.path
import pymysql
import sqlconfig # From sqlconfig.py
import pandas as pd
import sqlalchemy
print("Import Complete")
# Out:
# Import Complete

# %% [markdown]
# ### SQL setup
# create engine for CBAS db

# %%
passwd = sqlconfig.passwd  # From sqlconfig.py
user = sqlconfig.user  # From sqlconfig.py
DB = 'CBAS'  #name of databases to activate

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://'+user+':'+passwd+'@34.67.192.90/'+DB)

# %%
Aquery= ''' 
SELECT * 
FROM NewLab
WHERE sensor = 'protoCBAS-A' 
AND timestamp BETWEEN '2019-09-06 00:00:00' and '2019-09-30 11:59:00'
'''

# %%
# SQL syntax select ALL data in table
query= ''' 
SELECT * 
FROM NewLab
'''

# %%
#place query in CBAStest df

CBAStest =  pd.read_sql(query,engine,
                        index_col=["timestamp"])

# %%
CBAStest
# Out:
#                       battery  Tdb_BME680  RH_BME680  P_BME680  Alt_BME680  \
# timestamp
# 2019-09-06 15:59:00       NaN         NaN        NaN       NaN         NaN
# 2019-09-06 16:00:00       NaN         NaN        NaN       NaN         NaN
# 2019-09-06 16:00:00       NaN         NaN        NaN       NaN         NaN
# 2019-09-06 16:00:00       NaN         NaN        NaN       NaN         NaN
# 2019-09-06 20:20:00  3.972174     24.1600    55.7900  100.9500         NaN
# ...                       ...         ...        ...       ...         ...
# 2020-01-08 18:45:00  4.072067     29.6120    16.4960  101.3680         NaN
# 2020-01-08 18:50:00  4.071226     29.6075    16.5025  101.3775         NaN
# 2020-01-08 18:55:00  4.073863     29.6220    16.4320  101.3860         NaN
# 2020-01-08 19:00:00  4.072067     29.6400    16.3980  101.3920         NaN
# 2020-01-08 19:05:00  4.070384     29.6500    16.3750  101.4050         NaN
#
#                      TVOC   ECO2    RCO2  Tdb_scd30  RH_scd30  ...  \
# timestamp                                                      ...
# 2019-09-06 15:59:00   NaN    NaN     NaN        NaN       NaN  ...
# 2019-09-06 16:00:00   NaN    NaN     NaN        NaN       NaN  ...
# 2019-09-06 16:00:00   NaN    NaN     NaN        NaN       NaN  ...
# 2019-09-06 16:00:00   NaN    NaN     NaN        NaN       NaN  ...
# 2019-09-06 20:20:00   0.0  400.0  800.00    24.5800    56.380  ...
# ...                   ...    ...     ...        ...       ...  ...
# 2020-01-08 18:45:00   1.0  401.0  652.00    30.9380    15.948  ...
# 2020-01-08 18:50:00   1.0  401.0  657.25    30.9325    15.920  ...
# 2020-01-08 18:55:00   1.0  401.0  653.40    30.9440    15.858  ...
# 2020-01-08 19:00:00   1.0  401.0  654.00    30.9800    15.816  ...
# 2020-01-08 19:05:00   1.0  401.0  654.50    30.9650    15.675  ...
#
#                      PPD_fixed_air  Ta_adj_fixed_air  \
# timestamp
# 2019-09-06 15:59:00            NaN               NaN
# 2019-09-06 16:00:00            NaN               NaN
# 2019-09-06 16:00:00            NaN               NaN
# 2019-09-06 16:00:00            NaN               NaN
# 2019-09-06 20:20:00      30.305161         21.500962
# ...                            ...               ...
# 2020-01-08 18:45:00       5.770581         24.289067
# 2020-01-08 18:50:00       5.777206         24.286899
# 2020-01-08 18:55:00       5.759427         24.292882
# 2020-01-08 19:00:00       5.733962         24.301382
# 2020-01-08 19:05:00       5.720285         24.306018
#
#                      Cooling_effect_fixed_air  SET_fixed_air  TComf_fixed_air  \
# timestamp
# 2019-09-06 15:59:00                       NaN    -999.000000        25.076096
# 2019-09-06 16:00:00                       NaN    -999.000000        25.076096
# 2019-09-06 16:00:00                       NaN    -999.000000        25.076096
# 2019-09-06 16:00:00                       NaN    -999.000000        25.076096
# 2019-09-06 20:20:00                 20.325461       3.834539        25.076096
# ...                                       ...            ...              ...
# 2020-01-08 18:45:00                 26.969849       2.642151        28.185000
# 2020-01-08 18:50:00                 26.964500       2.643000        28.185000
# 2020-01-08 18:55:00                 26.981694       2.640306        28.185000
# 2020-01-08 19:00:00                 27.003081       2.636919        28.185000
# 2020-01-08 19:05:00                 27.014960       2.635040        28.185000
#
#                     TempDiff_fixed_air TComfLower_fixed_air  \
# timestamp
# 2019-09-06 15:59:00                NaN            21.576096
# 2019-09-06 16:00:00                NaN            21.576096
# 2019-09-06 16:00:00                NaN            21.576096
# 2019-09-06 16:00:00                NaN            21.576096
# 2019-09-06 20:20:00          -0.496096            21.576096
# ...                                ...                  ...
# 2020-01-08 18:45:00          -0.879000            24.685000
# 2020-01-08 18:50:00          -0.881250            24.685000
# 2020-01-08 18:55:00          -0.874000            24.685000
# 2020-01-08 19:00:00          -0.865000            24.685000
# 2020-01-08 19:05:00          -0.860000            24.685000
#
#                     TComfUpper_fixed_air  Acceptability_fixed_air  \
# timestamp
# 2019-09-06 15:59:00            28.576096                        0
# 2019-09-06 16:00:00            28.576096                        0
# 2019-09-06 16:00:00            28.576096                        0
# 2019-09-06 16:00:00            28.576096                        0
# 2019-09-06 20:20:00            28.576096                        1
# ...                                  ...                      ...
# 2020-01-08 18:45:00            33.885000                        1
# 2020-01-08 18:50:00            33.885000                        1
# 2020-01-08 18:55:00            33.885000                        1
# 2020-01-08 19:00:00            33.885000                        1
# 2020-01-08 19:05:00            33.885000                        1
#
#                      Condit_fixed_air
# timestamp
# 2019-09-06 15:59:00                -1
# 2019-09-06 16:00:00                -1
# 2019-09-06 16:00:00                -1
# 2019-09-06 16:00:00                -1
# 2019-09-06 20:20:00                 0
# ...                               ...
# 2020-01-08 18:45:00                 0
# 2020-01-08 18:50:00                 0
# 2020-01-08 18:55:00                 0
# 2020-01-08 19:00:00                 0
# 2020-01-08 19:05:00                 0
#
# [156586 rows x 57 columns]

# %% [markdown]
# Check which sensors are in this data set

# %%
print(CBAStest.sensor.unique())
# what unique values are in "sensor" column
print(type(CBAStest.index)) # check timestamp is recognized as DatetimeIndex
print(CBAStest.index.min())
print(CBAStest.index.max())
# min/max index valeus (date range)
# Out:
# ['protoCBAS-A' 'protoCBAS-B' 'protoCBAS-C' 'protoCBAS-D' 'protoCBAS-G']
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
# 2019-09-06 15:59:00
# 2020-01-08 19:05:00

# %% [markdown]
# ### So "CBAStest" is one dataframe
# * df date ranges from '2019-09-06 15:59:00' - '2020-01-08 19:05:00'
# * Sensors in this df ['protoCBAS-A', 'protoCBAS-B', 'protoCBAS-C', 'protoCBAS-D','protoCBAS-G']
#
# This is a bit different from how we usually managed dataframes where we had a list of dataframes for each sensor.
# ### options to manage (one df vs list of dfs):
# * grouping this df by "sensor" column into different dfs and place them in list
# * Use Pandas filtering/grouping as needed, only situation I see this needed is when ploting different sensors as seperate traces.

# %% [markdown]
# ### Further exploring the dataset...

# %%
print(CBAStest.columns)
# what columns do we have
# Out:
# Index(['battery', 'Tdb_BME680', 'RH_BME680', 'P_BME680', 'Alt_BME680', 'TVOC',
#        'ECO2', 'RCO2', 'Tdb_scd30', 'RH_scd30', 'Lux', 'PM1', 'PM25', 'PM10',
#        'Air', 'sensor_SD', 'note', 'sensor_note', 'Coord_X_m', 'Coord_Y_m',
#        'Coord_Z_m', 'Position_HumanReadable', 'Wkdy(EST)', 'Hour(EST)',
#        'Month(EST)', 'TOD(EST)', 'DOY(EST)', 'sensor', 'UTCI_approx',
#        'UTCI_comfortable', 'UTCI_stressRange', 'PMV', 'PPD', 'Ta_adj',
#        'Cooling_effect', 'SET', 'running_mean', 'TComf', 'TempDiff',
#        'TComfLower', 'TComfUpper', 'Acceptability', 'Condit',
#        'UTCI_approx_fixed_air', 'UTCI_comfortable_fixed_air',
#        'UTCI_stressRange_fixed_air', 'PMV_fixed_air', 'PPD_fixed_air',
#        'Ta_adj_fixed_air', 'Cooling_effect_fixed_air', 'SET_fixed_air',
#        'TComf_fixed_air', 'TempDiff_fixed_air', 'TComfLower_fixed_air',
#        'TComfUpper_fixed_air', 'Acceptability_fixed_air', 'Condit_fixed_air'],
#       dtype='object')

# %%
print(CBAStest.Position_HumanReadable.unique())
# unique values in Position_HumanReadable column
# Out:
# [None '2nd floor Mezz Across from Quiet Area' '2nd floor Mezz Quiet Area'
#  'Bridge (middle of bridge)' '"Wind Tunnel"' 'desk near supply vent'
#  'Supply vent' 'In Quiet Area, 2nd floor'
#  'Cubicles (Gnd floor west of event space)' 'Cubicles new desk'
#  'FA HQ (Gnd floor desks west of fishbowls)' 'Lynq loft ( 2nd floor)'
#  'bench under front staircase' 'welcome desk'
#  'central corridor (ground floor) cubicle']

# %% [markdown]
# Thinking how this will plot, and how this data differes from .CSV files usually used
# looking at extradata_to_static_dash.py script and how it manages dfs
#
# Some in script modifications to this data for plotting are:
# * Timezone convesion
#     Convert to NYC tz, index will need to be timezone aware to work
#     Code:
#     ```python
#     def tz_NYC(d):
#         d.index = d.index.tz_convert('America/New_York')
#         return d
#     dfs = list(map(tz_NYC, dfs))
#
#     ```
#     ---
# * Adjust for "gremlins" in CBAS-B CO2 sensor
# ```
# RCO2 data is offset by +782ppm from "2019-09-05 "-"2019-11-10 "
# after "2019-11-10 " CO2 seemed to report as it should.
# Made this tweak in January, not sure if anything has changed as of writing this (Mar-09)
# ```
#     ```python
#      dfs[1]["2019-09-05 ":"2019-11-10 "]["RCO2"] = (dfs[1]["2019-09-05 ":"2019-11-10 "]["RCO2"]-782) #adjust for gremlins in CBAS-B CO2 sensor
#
#     ```
#     ---
# * Remove "Wind Tunnel" testing
#     pull data reffering to Wind tunnel as it is not related to NewLab
# ```Python
# dfs = [d.loc[d["Position_HumanReadable"] != '"Wind Tunnel"'] for d in dfs]
# ```
# ---

# %% [markdown]
# ### Adjusting snippets for this data
#     My goal with this "NewLab" table is to have a dataset that is ready to pull and work with
#     requiring less redundant modifications.
#     So things like pulling out the wind tunnel testing and offsetting RCO@ for CBAS-B should be handled already

# %%
def tz_NYC(d): 
        d.index = d.index.tz_localize('UTC').tz_convert('America/New_York')
        return d

# %%
CBASNYC = tz_NYC(CBAStest) # data in db shoudl stay as UTC, only convert just before displaying

# %%
CBASNYC.head()
# Out:
#                             battery  Tdb_BME680  RH_BME680  P_BME680  \
# timestamp
# 2019-09-06 11:59:00-04:00       NaN         NaN        NaN       NaN
# 2019-09-06 12:00:00-04:00       NaN         NaN        NaN       NaN
# 2019-09-06 12:00:00-04:00       NaN         NaN        NaN       NaN
# 2019-09-06 12:00:00-04:00       NaN         NaN        NaN       NaN
# 2019-09-06 16:20:00-04:00  3.972174       24.16      55.79    100.95
#
#                            Alt_BME680  TVOC   ECO2   RCO2  Tdb_scd30  \
# timestamp
# 2019-09-06 11:59:00-04:00         NaN   NaN    NaN    NaN        NaN
# 2019-09-06 12:00:00-04:00         NaN   NaN    NaN    NaN        NaN
# 2019-09-06 12:00:00-04:00         NaN   NaN    NaN    NaN        NaN
# 2019-09-06 12:00:00-04:00         NaN   NaN    NaN    NaN        NaN
# 2019-09-06 16:20:00-04:00         NaN   0.0  400.0  800.0      24.58
#
#                            RH_scd30  ...  PPD_fixed_air  Ta_adj_fixed_air  \
# timestamp                            ...
# 2019-09-06 11:59:00-04:00       NaN  ...            NaN               NaN
# 2019-09-06 12:00:00-04:00       NaN  ...            NaN               NaN
# 2019-09-06 12:00:00-04:00       NaN  ...            NaN               NaN
# 2019-09-06 12:00:00-04:00       NaN  ...            NaN               NaN
# 2019-09-06 16:20:00-04:00     56.38  ...      30.305161         21.500962
#
#                            Cooling_effect_fixed_air  SET_fixed_air  \
# timestamp
# 2019-09-06 11:59:00-04:00                       NaN    -999.000000
# 2019-09-06 12:00:00-04:00                       NaN    -999.000000
# 2019-09-06 12:00:00-04:00                       NaN    -999.000000
# 2019-09-06 12:00:00-04:00                       NaN    -999.000000
# 2019-09-06 16:20:00-04:00                 20.325461       3.834539
#
#                            TComf_fixed_air TempDiff_fixed_air  \
# timestamp
# 2019-09-06 11:59:00-04:00        25.076096                NaN
# 2019-09-06 12:00:00-04:00        25.076096                NaN
# 2019-09-06 12:00:00-04:00        25.076096                NaN
# 2019-09-06 12:00:00-04:00        25.076096                NaN
# 2019-09-06 16:20:00-04:00        25.076096          -0.496096
#
#                           TComfLower_fixed_air TComfUpper_fixed_air  \
# timestamp
# 2019-09-06 11:59:00-04:00            21.576096            28.576096
# 2019-09-06 12:00:00-04:00            21.576096            28.576096
# 2019-09-06 12:00:00-04:00            21.576096            28.576096
# 2019-09-06 12:00:00-04:00            21.576096            28.576096
# 2019-09-06 16:20:00-04:00            21.576096            28.576096
#
#                            Acceptability_fixed_air  Condit_fixed_air
# timestamp
# 2019-09-06 11:59:00-04:00                        0                -1
# 2019-09-06 12:00:00-04:00                        0                -1
# 2019-09-06 12:00:00-04:00                        0                -1
# 2019-09-06 12:00:00-04:00                        0                -1
# 2019-09-06 16:20:00-04:00                        1                 0
#
# [5 rows x 57 columns]

# %%
CBAStestxwind = CBAStest.loc[CBAStest["Position_HumanReadable"] != '"Wind Tunnel"']

# %%
print(CBAStestxwind.Position_HumanReadable.unique())
# Out:
# [None '2nd floor Mezz Across from Quiet Area' '2nd floor Mezz Quiet Area'
#  'Bridge (middle of bridge)' 'desk near supply vent' 'Supply vent'
#  'In Quiet Area, 2nd floor' 'Cubicles (Gnd floor west of event space)'
#  'Cubicles new desk' 'FA HQ (Gnd floor desks west of fishbowls)'
#  'Lynq loft ( 2nd floor)' 'bench under front staircase' 'welcome desk'
#  'central corridor (ground floor) cubicle']

# %%
Aquery= ''' 
SELECT * 
FROM NewLab
WHERE sensor = 'protoCBAS-A' 
AND timestamp BETWEEN '2019-09-06 00:00:00' and '2019-09-30 11:59:00'
'''


CBAStestA =  pd.read_sql(Aquery,engine,parse_dates=["timestamp"], index_col=["timestamp"])

# %%
CBAStestA.head()
# Out:
#                       battery  Tdb_BME680  RH_BME680  P_BME680  Alt_BME680  \
# timestamp
# 2019-09-06 15:59:00       NaN         NaN        NaN       NaN         NaN
# 2019-09-06 16:00:00       NaN         NaN        NaN       NaN         NaN
# 2019-09-06 16:00:00       NaN         NaN        NaN       NaN         NaN
# 2019-09-06 16:00:00       NaN         NaN        NaN       NaN         NaN
# 2019-09-06 20:20:00  3.972174       24.16      55.79    100.95         NaN
#
#                      TVOC   ECO2   RCO2  Tdb_scd30  RH_scd30  ...  \
# timestamp                                                     ...
# 2019-09-06 15:59:00   NaN    NaN    NaN        NaN       NaN  ...
# 2019-09-06 16:00:00   NaN    NaN    NaN        NaN       NaN  ...
# 2019-09-06 16:00:00   NaN    NaN    NaN        NaN       NaN  ...
# 2019-09-06 16:00:00   NaN    NaN    NaN        NaN       NaN  ...
# 2019-09-06 20:20:00   0.0  400.0  800.0      24.58     56.38  ...
#
#                      PPD_fixed_air  Ta_adj_fixed_air  \
# timestamp
# 2019-09-06 15:59:00            NaN               NaN
# 2019-09-06 16:00:00            NaN               NaN
# 2019-09-06 16:00:00            NaN               NaN
# 2019-09-06 16:00:00            NaN               NaN
# 2019-09-06 20:20:00      30.305161         21.500962
#
#                      Cooling_effect_fixed_air  SET_fixed_air  TComf_fixed_air  \
# timestamp
# 2019-09-06 15:59:00                       NaN    -999.000000        25.076096
# 2019-09-06 16:00:00                       NaN    -999.000000        25.076096
# 2019-09-06 16:00:00                       NaN    -999.000000        25.076096
# 2019-09-06 16:00:00                       NaN    -999.000000        25.076096
# 2019-09-06 20:20:00                 20.325461       3.834539        25.076096
#
#                     TempDiff_fixed_air TComfLower_fixed_air  \
# timestamp
# 2019-09-06 15:59:00                NaN            21.576096
# 2019-09-06 16:00:00                NaN            21.576096
# 2019-09-06 16:00:00                NaN            21.576096
# 2019-09-06 16:00:00                NaN            21.576096
# 2019-09-06 20:20:00          -0.496096            21.576096
#
#                     TComfUpper_fixed_air  Acceptability_fixed_air  \
# timestamp
# 2019-09-06 15:59:00            28.576096                        0
# 2019-09-06 16:00:00            28.576096                        0
# 2019-09-06 16:00:00            28.576096                        0
# 2019-09-06 16:00:00            28.576096                        0
# 2019-09-06 20:20:00            28.576096                        1
#
#                      Condit_fixed_air
# timestamp
# 2019-09-06 15:59:00                -1
# 2019-09-06 16:00:00                -1
# 2019-09-06 16:00:00                -1
# 2019-09-06 16:00:00                -1
# 2019-09-06 20:20:00                 0
#
# [5 rows x 57 columns]

# %%
CBAStestA.sensor
# Out:
# timestamp
# 2019-09-06 15:59:00    protoCBAS-A
# 2019-09-06 16:00:00    protoCBAS-A
# 2019-09-06 16:00:00    protoCBAS-A
# 2019-09-06 16:00:00    protoCBAS-A
# 2019-09-06 20:20:00    protoCBAS-A
#                           ...
# 2019-09-30 11:35:00    protoCBAS-A
# 2019-09-30 11:40:00    protoCBAS-A
# 2019-09-30 11:45:00    protoCBAS-A
# 2019-09-30 11:50:00    protoCBAS-A
# 2019-09-30 11:55:00    protoCBAS-A
# Name: sensor, Length: 6903, dtype: object
